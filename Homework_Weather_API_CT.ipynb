# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#api_key:"39249da59acc1672b2f1d61c94d29d04"

# %%
from api_keys import api_key

from citipy import citipy

output_data_file = "output_data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 613

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")
for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
         
        record= record + 1
        
        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39249da59acc1672b2f1d61c94d29d04&q=coquimbo
# City not found. Skipping...
# Processing Record 2 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39249da59acc1672b2f1d61c94d29d04&q=husavik
# City not found. Skipping...
# Processing Record 3 | Benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39249da59acc1672b2f1d61c94d29d04&q=benghazi
# Processing Record 4 | Slawno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39249da59acc1672b2f1d61c94d29d04&q=slawno
# Processing Record 5 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39249da59acc1672b2f1d61c94d29d04&q=ancud
# Processing Record 6 | Puerto Penasco
# ...

# %%
weatherpy_dict = {"City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}

weather_data = pd.DataFrame(weatherpy_dict) 
weather_data.count()
# Out:
# City          533
# Cloudiness    533
# Country       533
# Date          533
# Humidity      533
# Lat           533
# Lng           533
# Max Temp      533
# Wind Speed    533
# dtype: int64

# %%
weather_data.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat    Lng  Max Temp  \
# 0  Coquimbo           0      CL  1570315491        71 -29.95 -71.34      57.2
# 1   Husavik         100      CA  1570315595        93  50.56 -96.99      45.0
# 2  Benghazi           0      LY  1570315596        59  32.12  20.07      74.4
# 3    Slawno           0      PL  1570315598        93  52.84  16.56      39.0
# 4     Ancud          90      CL  1570315599        71 -41.87 -73.83      50.0
#
#    Wind Speed
# 0       12.75
# 1        8.99
# 2        9.37
# 3        3.36
# 4        8.05

# %%
weather_data.to_csv('../Output_CSVweather_data.csv')

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=30)

plt.title("City Latitude vs. Max Temperature 4/12/2018")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Output_PlotsMax_Temp_vs_Latitude.png")

plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=30)

plt.title("City Latitude vs. Humidity 8/22/2018")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Output_PlotsHumidity_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=30)

plt.title("City Latitude vs. Cloudiness 10/22/2018")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("../Output_PlotsCloudiness_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=30)

plt.title("City Latitude vs. Wind Speed 12/15/2018")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("../Output_PlotsWind_Speed_vs_Latitude.png")
plt.show()
